# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datetime import datetime as dt, timedelta
from random import randrange

# %matplotlib inline

# %% [markdown]
# ## Load cleaned data

# %%
data = pd.read_csv("data/data_cleaned_full.csv")

# %%
data
# Out:
#                                                    Image  \
# 0      https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 1      https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 2      https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 3      https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 4      https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# ...                                                  ...
# 18822  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18823  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18824  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18825  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18826  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
#
#                                                    Title  \
# 0                                  This is Going to Hurt
# 1                                Thinking, Fast and Slow
# 2                                When Breath Becomes Air
# ...

# %% [markdown]
# ## Mapping Category-Subcategory

# %%
data.Category.unique()
# Out:
# array(['Medical', 'Science-Geography', 'Art-Photography', 'Biography',
#        'Business-Finance-Law', 'Childrens-Books', 'Computing',
#        'Crafts-Hobbies', 'Crime-Thriller', 'Dictionaries-Languages',
#        'Entertainment', 'Food-Drink', 'Graphic-Novels-Anime-Manga',
#        'Health', 'History-Archaeology', 'Home-Garden', 'Humour',
#        'Mind-Body-Spirit', 'Natural-History', 'Personal-Development',
#        'Poetry-Drama', 'Reference', 'Religion', 'Romance',
#        'Science-Fiction-Fantasy-Horror', 'Society-Social-Sciences',
#        'Sport', 'Stationery', 'Teaching-Resources-Education',
#        'Technology-Engineering', 'Teen-Young-Adult', 'Transport',
#        'Travel-Holiday-Guides'], dtype=object)

# %%
Categories = [x for x in data.Category.unique()]
Categories
# Out:
# ['Medical',
#  'Science-Geography',
#  'Art-Photography',
#  'Biography',
#  'Business-Finance-Law',
#  'Childrens-Books',
#  'Computing',
#  'Crafts-Hobbies',
#  'Crime-Thriller',
#  'Dictionaries-Languages',
#  'Entertainment',
#  'Food-Drink',
#  'Graphic-Novels-Anime-Manga',
#  'Health',
#  'History-Archaeology',
#  'Home-Garden',
#  'Humour',
#  'Mind-Body-Spirit',
#  'Natural-History',
#  'Personal-Development',
#  'Poetry-Drama',
#  'Reference',
#  'Religion',
#  'Romance',
#  'Science-Fiction-Fantasy-Horror',
#  'Society-Social-Sciences',
#  'Sport',
#  'Stationery',
#  'Teaching-Resources-Education',
#  'Technology-Engineering',
#  'Teen-Young-Adult',
#  'Transport',
#  'Travel-Holiday-Guides']

# %%
catDescriptions = {
    'Medical': 'For those in field of medicine, learn about diseases, cure and much more',
    'Science-Geography': 'Educational books to keep one\'s thirst for knowledge sated',
    'Art-Photography': 'Indulge in fine arts, heritage and culture',
    'Biography': 'The thrilling tales of renowned individuals',
    'Business-Finance-Law': 'Stocks, marketing and investments',
    'Childrens-Books': 'Let fantasies run wild as the young ones set off on their journey to uncover the endless mysteries of the world',
    'Computing': 'The revolution of computing and information',
    'Crafts-Hobbies': 'Creative Crafting Hobbies to Take Up',
    'Crime-Thriller': 'Let the inner sherlock soar!',
    'Dictionaries-Languages': 'Meaning and definitions of words',
    'Entertainment': 'Invented for the purposes of fiction',
    'Food-Drink': 'Exciting delicacies to be had around the world',
    'Graphic-Novels-Anime-Manga': 'For all the Otakus out there!',
    'Health': 'Best practices for staying healthy and 100% efficient',
    'History-Archaeology': 'Archaeological surveys and discoveries',
    'Home-Garden': 'The decoration and scenery of a stage',
    'Humour': 'Comic relief to pass time on',
    'Mind-Body-Spirit': 'Let go of stress, being mindful of ones desires and inner workings',
    'Natural-History': 'literatures based in facts and natural history',
    'Personal-Development': '<Description>',
    'Poetry-Drama': '<Description>',
    'Reference': 'Miscellaneous',
    'Religion': '<Description>',
    'Romance': '<Description>',
    'Science-Fiction-Fantasy-Horror': '<Description>',
    'Society-Social-Sciences': 'Understanding and learning on effectiveness of society and best practices to improve',
    'Sport': 'Sports and atheletics',
    'Stationery': 'Best tools and information on using them',
    'Teaching-Resources-Education': '<Description>',
    'Technology-Engineering': '<Description>',
    'Teen-Young-Adult': '<Description>',
    'Transport': 'Getting from A to B, the best routes and commute means to adopt',
    'Travel-Holiday-Guides': 'Travel guides and best locations'
}

# %%
catImages = {
    'Education': 'https://images.unsplash.com/photo-1503676260728-1c00da094a0b?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2022&q=80',
    'Travel': 'https://images.unsplash.com/photo-1488646953014-85cb44e25828?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1935&q=80',
    'Art, Music & Photography': 'https://images.unsplash.com/photo-1535083988052-565ca9546643?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=580&q=80',
    'Finance': 'https://images.unsplash.com/photo-1567427017947-545c5f8d16ad?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=806&q=80',
    'Information Technology': 'https://images.unsplash.com/photo-1498050108023-c5249f4df085?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1172&q=80',
    'Fictional': 'https://images.unsplash.com/photo-1609488895842-cd46eaf42e14?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=581&q=80',
    'Non-Fictional': 'https://images.unsplash.com/photo-1476950743170-ab77e7d4d82e?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1211&q=80',
    'Personal-care': 'https://images.unsplash.com/photo-1506126613408-eca07ce68773?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=499&q=80',
    'Comic relief': 'https://images.unsplash.com/photo-1608889825271-9696283ab804?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Decor': 'https://images.unsplash.com/photo-1513519245088-0e12902e5a38?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1170&q=80',
    'Misc': 'https://images.unsplash.com/photo-1587250596956-b708d6293843?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=327&q=80',
    'Medical': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Science-Geography': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Art-Photography': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Biography': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Business-Finance-Law': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Childrens-Books': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Computing': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Crafts-Hobbies': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Crime-Thriller': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Dictionaries-Languages': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Entertainment': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Food-Drink': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Graphic-Novels-Anime-Manga': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Health': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'History-Archaeology': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Home-Garden': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Humour': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Mind-Body-Spirit': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Natural-History': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Personal-Development': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Poetry-Drama': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Reference': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Religion': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Romance': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Science-Fiction-Fantasy-Horror': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Society-Social-Sciences': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Sport': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Stationery': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Teaching-Resources-Education': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Technology-Engineering': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Teen-Young-Adult': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Transport': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80',
    'Travel-Holiday-Guides': 'https://images.unsplash.com/photo-1576158129799-c4a7a6436de4?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=580&q=80'
}

# %% [markdown]
# ## Project Design
#
# * User roles - Customer, Admin
#     * **Admin**
#         * Admin has authority to activate/deactivate customer accounts, as well as view orders placed by customers.
#         * Admin adds coupon codes that can be redeemed by the customers to avail discounts on products.
#     * **Customer**
#         * Customer can search for books by its name, author, isbn or category
#         * Can only see books that have their status == "show".
#         * Can add/remove books to/from wishlist.
#         * Can add/remove books to/from cart
#         * Can manage cart - add/remove/modify quantity and so on.
#         * Must be logged in to place order.
#         * Can add shipping/billing addresses, which can be reused later
#         * Able to apply discount coupons in payment page.
# * Featured books section - Sponsored/advertised books are displayed
# * New books - displays the latest books.
# * **Category**:
#     - catId
#     - catName
#     - catDescription
#     - position
#     - status
#     - image
#     - createdAt
# &nbsp;&nbsp;Category is to be sorted by position, and only those category that have their status == "show" are to be made visible to customers.
# * **Book**:
#     - BookID
#     - CatID
#     - Title
#     - ISBN
#     - Year
#     - Price
#     - Description
#     - Position
#     - Status
#     - Image

# %% [markdown]
# ### Initializing dict for dataset

# %%
Category_dict = {
    'CatID': [],
    'CatName': [],
    'CatDescription': [],
    'Position': [],
    'Status': [],
    'Image': [],
    'CreatedAt': []
}

# %% [markdown]
# ## Populating data

# %%
def random_date():
    start = dt.strptime('1/1/1973', '%m/%d/%Y')
    end = dt.strptime('10/13/2021', '%m/%d/%Y')
    
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    date = start + timedelta(seconds=random_second)
    return date.strftime('%Y/%m/%d')

# %%
_pos = 1
for cat in Categories:
    _id = 'cat' + (str(_pos) if len(str(_pos))>1 else '0'+str(_pos))
    Category_dict['CatID'].append(_id)
    Category_dict['CatName'].append(cat)
    Category_dict['CatDescription'].append(catDescriptions[cat])
    Category_dict['Position'].append(_pos)
    Category_dict['Status'].append('Available')
    Category_dict['Image'].append(catImages[cat])
    _date = random_date() 
    Category_dict['CreatedAt'].append(random_date())
    _pos += 1

# %% [markdown]
# ## Creating Dataframe

# %%
Category_df = pd.DataFrame(Category_dict)

# %% [markdown]
# ## Display data

# %%
Category_df.head(10)
# Out:
#    CatID                 CatName  \
# 0  cat01                 Medical
# 1  cat02       Science-Geography
# 2  cat03         Art-Photography
# 3  cat04               Biography
# 4  cat05    Business-Finance-Law
# 5  cat06         Childrens-Books
# 6  cat07               Computing
# 7  cat08          Crafts-Hobbies
# 8  cat09          Crime-Thriller
# 9  cat10  Dictionaries-Languages
#
#                                       CatDescription  Position     Status  \
# 0  For those in field of medicine, learn about di...         1  Available
# 1  Educational books to keep one's thirst for kno...         2  Available
# 2         Indulge in fine arts, heritage and culture         3  Available
# 3        The thrilling tales of renowned individuals         4  Available
# 4                  Stocks, marketing and investments         5  Available
# 5  Let fantasies run wild as the young ones set o...         6  Available
# ...

# %% [markdown]
# ## Saving Category

# %%
Category_df.to_csv('./data/CategoryTable.csv', index=False)

# %% [markdown]
# ## Augmenting Books

# %%
def AugmCatID(row):
    _catID = Category_df[Category_df['CatName'] == row].CatID.to_string().split(' ')[-1]
    return _catID
def randomizedDate(row):
    return random_date()
_pos = 0
def positions(row):
    global _pos
    _pos+=1
    return _pos
def setStatus(row):
    return "Available"
def setDescription(row):
    return ""

# %%
data['CatID'] = data['Category'].apply(AugmCatID)
data['Year'] = data['CatID'].apply(randomizedDate)
data['Position'] = data['CatID'].apply(positions)
data['Status'] = data['CatID'].apply(setStatus)
data['Description'] = data['CatID'].apply(setDescription)

# %%
data.head()
# Out:
#                                                Image  \
# 0  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 1  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 2  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 3  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 4  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
#
#                                     Title           Author     Format  Rating  \
# 0                   This is Going to Hurt         Adam Kay  Paperback     4.5
# 1                 Thinking, Fast and Slow  Daniel Kahneman  Paperback     4.0
# 2                 When Breath Becomes Air   Paul Kalanithi  Paperback     4.5
# 3                      The Happiness Trap      Russ Harris  Paperback     4.0
# 4  The Man Who Mistook His Wife for a Hat     Oliver Sacks  Paperback     4.0
#
#    Price  OldPrice           ISBN Category  CatID        Year  Position  \
# 0   7.60      11.4  9781509858637  Medical  cat01  2001/06/17         1
# ...

# %%
data.drop('Category', axis = 1, inplace = True)

# %%
lengths = {}
for col in data.columns:
    min_len = 0
    for iterate in data[col]:
        if(len(str(iterate)) > min_len):
            min_len = len(str(iterate))
    lengths[col] = min_len
lengths
# Out:
# {'Image': 88,
#  'Title': 206,
#  'Author': 51,
#  'Format': 22,
#  'Rating': 3,
#  'Price': 6,
#  'OldPrice': 6,
#  'ISBN': 13,
#  'CatID': 5,
#  'Year': 10,
#  'Position': 5,
#  'Status': 9,
#  'Description': 0}

# %%
data.dtypes
# Out:
# Image           object
# Title           object
# Author          object
# Format          object
# Rating         float64
# Price          float64
# OldPrice       float64
# ISBN             int64
# CatID           object
# Year            object
# Position         int64
# Status          object
# Description     object
# dtype: object

# %% [markdown]
# ## Saving augmented data

# %%
data.to_csv('./data/BooksTable [Augmented].csv', index = False)
